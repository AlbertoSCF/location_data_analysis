# %%
import pandas as pd

# %%
data = pd.read_csv('data/robo/DadosBO_2021_1(FURTO DE VEÍCULOS).csv', 
                   sep=';', 
                   encoding='latin-1', 
                   on_bad_lines='skip')

# %%
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 DadosBO_2021_1(FURTO DE VEIÌCULOS)
# ...
